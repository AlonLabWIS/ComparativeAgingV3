# %%
# %load_ext autoreload
# %autoreload 2
import os
#change current working directory to the parent directory
import sys

# Change working directory to ../ only if not already there
if not hasattr(sys, "_parent_dir_set"):
    parent_dir = os.path.abspath(os.path.join(os.getcwd(), ".."))
    if os.getcwd() != parent_dir:
        os.chdir(parent_dir)
    sys._parent_dir_set = parent_dir
else:
    parent_dir = sys._parent_dir_set
# Add parent_dir to sys.path only if not already present
if parent_dir not in sys.path:
    sys.path.insert(0, parent_dir)

import numpy as np
from SRtools import sr_mcmc as srmc
import argparse
from SRtools import config_lib as cl
from SRtools import deathTimesDataSet as dtds
import ast
from SRtools import readResults as rr
import corner
import matplotlib.pyplot as plt
import matplotlib
from SRtools import SRmodellib as sr
from SRtools import SRmodellib_lifelines as srl
import emcee
from SRtools import samples_utils as su
from SRtools import joint_posterior as jp
from SRtools import SR_hetro as srh
from SRtools import life_table as lt

# %%
from numpy import True_


configs_names = ['Sweden_M_1910_hetro','Denmark_M_1900_hetro','Denmark_M_1890_hetro']
data_config = 'Sweden_M_1910_hetro'

master_config_name = 'combined_human_M'

config_path = f"configurations_baysian.xlsx"

base_products_folder = os.path.join('analysis','products_baysian')
subfolder = None




summery_file_name = None
help_text ="joint posterior for combined human data"
apply_thresh = True


# POST_CREATED =False
SAVE_PRODUCTS =True
FAST = False
parallel = True
override = True
auto_thresh = True
thresh_max = 300

# %%
#get the name of current folder:
current_folder = os.path.basename(os.getcwd())

# %%
posts =[]
master_post_path = os.path.join(base_products_folder,'posteriors', master_config_name+'_post.csv')

for config_name in configs_names:
    config = cl.read_excel_config(config_path, config_name)
    cfg = cl.config_to_dict(config, mcmc_convert=True)
    test_mode = bool(int(cfg.get('test', 0)))
    if test_mode:
        test_idx = 1  # Use test index 0
        post_path = os.path.join(base_products_folder,'posteriors', config_name+f'_{test_idx}_post.csv')
    else:    
        post_path = os.path.join(base_products_folder,'posteriors', config_name+'_post.csv')
    # Make sure the posterior directory exists before anything else
    posterior_dir = os.path.join(base_products_folder, 'posteriors')




    post = su.Posterior.load_from_file(post_path)
    posts.append(post)
    #########################################################
    if config_name == data_config:
        data_config_post = post

        config_dict =post.config_params
        npeople = config_dict['npeople']
        t_end = config_dict['t_end']
        nwalkers = config_dict['nwalkers']
        nsteps = config_dict['nsteps']
        num_mcmc_steps = config_dict['n_mcmc_steps']
        metric = config_dict['metric']
        time_range = config_dict.get('time_range',None)
        time_step_multiplier = config_dict['time_step_multiplier']
        data_file = config_dict.get('data_file',None)
        seed_file = config_dict.get('seed_file',None)
        variations = config_dict.get('variations')
        prior = config_dict.get('prior')
        transform = config_dict.get('transform',True)
        index = config_dict.get('index',1)
        external_hazard = config_dict.get('external_hazard',None)
        if isinstance(external_hazard, str):
            external_hazard = ast.literal_eval(external_hazard)
        hetro = config_dict.get('hetro', False)
        submission_folder = config_dict['submission_folder']
        test_mode = bool(int(config_dict.get('test', 0)))
        n_tests = config_dict.get('n_tests', 1)
        ndims = config_dict.get('ndims', 4)
        dt = config_dict.get('dt',1)
        nbins = int(config_dict.get('nbins',100))
        TIME_UNIT = config_dict.get('TIME_UNIT','days')



        #all paths are in absolute paths (start with ~/). change all paths to be relative to the current folder 
        # (remove everything before the current folder name)
        submission_folder = submission_folder.split(current_folder)[-1]
        #remove the first / from the paths

        submission_folder = submission_folder[1:]

        # In test mode, adjust paths to use test index subfolder
        if test_mode:
            name = str(cfg.get('name'))
            # Store base submission folder for datasets path
            base_submission_folder = submission_folder
            # Modify submission_folder to point to test subfolder
            submission_folder = f"{submission_folder}/test_{test_idx}"
            # Modify data_file to point to dataset in test mode (datasets are at base submission level)
            datasets_folder = f"{base_submission_folder}/datasets"
            data_file = f"{datasets_folder}/{name}_dataset_{test_idx}.csv"
        else:
            data_file = data_file.split(current_folder)[-1]
            data_file = data_file[1:]
            
        h5_folder = f"{submission_folder}/h5_files"

# %%
if test_mode:
    test_str = f'_test_{test_idx}'
else:
    test_str = ''

config_name = master_config_name

if SAVE_PRODUCTS:
    Products_folder = base_products_folder

    if subfolder is not None:
        path = os.path.join(Products_folder,subfolder, config_name+test_str)
        results_path = os.path.join(Products_folder,'results_csvs',subfolder,config_name+test_str+'result_table.csv')
        path_days = os.path.join(Products_folder,'results_csvs_days',config_name+test_str+'result_table_days.csv')
    else:
        path = os.path.join(Products_folder, config_name)
        results_path = os.path.join(Products_folder,'results_csvs',config_name+test_str+'result_table.csv')
        path_days = os.path.join(Products_folder,'results_csvs_days',config_name+test_str+'result_table_days.csv')
    # Create all necessary directories if they don't exist
    os.makedirs(os.path.dirname(results_path), exist_ok=True)
    os.makedirs(os.path.dirname(path_days), exist_ok=True)
    os.makedirs(path, exist_ok=True)
else:
    results_path=None
    path_days=None
    path=None

if TIME_UNIT == 'days':
    scale = None
elif TIME_UNIT == 'hours':
    scale = 1/24
elif TIME_UNIT == 'years':
    scale = 365
elif TIME_UNIT == 'weeks':
    scale = 7
elif TIME_UNIT == 'generations':
    scale = 1/8
else:
    raise ValueError(f"Invalid TIME_UNIT: {TIME_UNIT}")



# print(f"Loading file from: {path}")

# %%
ds = dtds.dsFromFile(data_file, properties=['death dt'])
ds.external_hazard = external_hazard
eta = float(cfg.get('eta'))
beta = float(cfg.get('beta'))
epsilon = float(cfg.get('epsilon'))
xc = float(cfg.get('xc'))
seed_ExtH = cfg.get('ExtH',None)
if seed_ExtH is not None and seed_ExtH != '':
    seed_ExtH = float(seed_ExtH)
else:
    seed_ExtH = None
seed = [eta,beta,epsilon,xc,seed_ExtH]
seed = seed[0:ndims]
if transform:
    seed_trans = srmc.transform(seed)

# %%
samples_list = []
lnprobs_list = []
for pos in posts:
    samples = pos.samples
    if len(samples[0,:]) == 5:
        # Remove the external hazard from the samples array
        samples = samples[:, :-1]
    
    samples_list.append(samples)
    lnprobs_list.append(pos.lnprobs)

post = jp.JointPosterior(samples_list, lnprobs_list, nbins, log=True,config_params=config_dict,help_text=help_text)
if post_path is not None:
    post.save_to_file(master_post_path)


best_theta_trans = post.get_mode()
# Out:
# Binning samples: 100%|██████████| 4/4 [00:00<00:00, 141.73it/s]
# Processing samples: 100%|██████████| 108683/108683 [00:00<00:00, 657871.29it/s]
# Averaging log-probabilities: 100%|██████████| 1597/1597 [00:00<00:00, 364632.74it/s]
# Processing unique samples for set 0: 100%|██████████| 1597/1597 [00:00<00:00, 441753.18it/s]
# Binning samples: 100%|██████████| 4/4 [00:00<00:00, 119.60it/s]
# Processing samples: 100%|██████████| 119400/119400 [00:00<00:00, 626068.74it/s]
# Averaging log-probabilities: 100%|██████████| 1626/1626 [00:00<00:00, 291612.36it/s]
# Processing unique samples for set 1: 100%|██████████| 1626/1626 [00:00<00:00, 441734.46it/s]
# Binning samples: 100%|██████████| 4/4 [00:00<00:00, 108.30it/s]
# Processing samples: 100%|██████████| 160103/160103 [00:00<00:00, 772302.23it/s]
# Averaging log-probabilities: 100%|██████████| 1954/1954 [00:00<00:00, 278347.71it/s]
# Processing unique samples for set 2: 100%|██████████| 1954/1954 [00:00<00:00, 502185.66it/s]

# %%
if test_mode:
    truths_trans =seed_trans
    truths = seed
else:
    truths_trans = best_theta_trans

# %%
labels_trans = ["$x_c/\\eta$","$\\beta/\\eta$","$x_c^2/\\epsilon$","$x_c$","EextH"]
labels_trans = labels_trans[0:4]

# %% [markdown]
# # 3. Posterior distributions of parameters
#
# 1d marginalizations of posterior distributions. we use a grid of size nbins=100-150

# %%
post.plot_1d_posteriors(labels=labels_trans, truths=truths_trans,scale='log',show_ln_prob=False,smooth_mode=False)

# %% [markdown]
# 2D marginalizations of posterior distributions

# %%
if not FAST:
    _=post.corner_plot(labels=labels_trans, truths=truths_trans,scale='log',show_ln_prob=False,norm='log',plot_type="pcolormesh")
# Out:
# Creating corner plot:   0%|          | 0/4 [00:00<?, ?it/s]/Volumes/alon/navehr/SRtools/SRtools/samples_utils.py:474: UserWarning: The input coordinates to pcolormesh are interpreted as cell centers, but are not monotonically increasing or decreasing. This may lead to incorrectly calculated cell edges, in which case, please supply explicit cell edges to pcolormesh.
#   ax.pcolormesh(X, Y, Z, **kwargs)
# Creating corner plot: 100%|██████████| 4/4 [00:02<00:00,  1.78it/s]

# %%
fig =post.plot_posterior3D_interactive([0,1,2],labels=labels_trans, truths=np.log(truths_trans),truth_label="Best fit" )
# Save the figure using matplotlib's savefig instead of plotly's write_image
fig.show()
if SAVE_PRODUCTS:
    # Save the figure as HTML
    html_file_name = master_config_name+test_str+'_3D_plot'
    if subfolder is not None:
        html_file_name = os.path.join(subfolder, html_file_name)
    html_path = os.path.join(Products_folder, 'html_3d_plots', f'{html_file_name}.html')
    # Create directory if it doesn't exist
    os.makedirs(os.path.dirname(html_path), exist_ok=True)
    fig.write_html(html_path)

# %%
best_theta =srmc.inv_transform(best_theta_trans)

# %%
if ndims == 5:
    external_hazard_estimate = best_theta[-1]
else:
    external_hazard_estimate = None
best_sim = srh.getSrHetro(best_theta, nsteps=nsteps, npeople=npeople, time_step_multiplier=time_step_multiplier, t_end=t_end, external_hazard=external_hazard_estimate,hetro =hetro,parallel=parallel)
best_sim_no_ext_hazard = srh.getSrHetro(best_theta, nsteps=nsteps, npeople=npeople, time_step_multiplier=time_step_multiplier, t_end=t_end, external_hazard=None,hetro =hetro,parallel=parallel)

# %%
if SAVE_PRODUCTS:
    save_path = results_path
else:
    save_path = None
if test_mode:
    truth_df = seed_trans
else:
    truth_df =None
df=post.create_posterior_df(filepath=save_path, ds = [best_sim_no_ext_hazard,best_sim,ds], ds_labels=['best fit no ext hazard','best fit','data'],truth=truth_df)
# Out:
# Binning samples: 100%|██████████| 4/4 [00:00<00:00, 99.46it/s]
# Processing samples: 100%|██████████| 108683/108683 [00:00<00:00, 336299.46it/s]
# Averaging log-probabilities: 100%|██████████| 1597/1597 [00:00<00:00, 127100.12it/s]
# Processing unique samples for set 0: 100%|██████████| 1597/1597 [00:00<00:00, 227779.22it/s]
# Binning samples: 100%|██████████| 4/4 [00:00<00:00, 56.33it/s]
# Processing samples: 100%|██████████| 119400/119400 [00:00<00:00, 417262.31it/s]
# Averaging log-probabilities: 100%|██████████| 1626/1626 [00:00<00:00, 102160.65it/s]
# Processing unique samples for set 1: 100%|██████████| 1626/1626 [00:00<00:00, 219877.43it/s]
# Binning samples: 100%|██████████| 4/4 [00:00<00:00, 43.17it/s]
# Processing samples: 100%|██████████| 160103/160103 [00:00<00:00, 372580.40it/s]
# Averaging log-probabilities: 100%|██████████| 1954/1954 [00:00<00:00, 121178.57it/s]
# Processing unique samples for set 2: 100%|██████████| 1954/1954 [00:00<00:00, 370224.96it/s]
# Binning samples: 100%|██████████| 4/4 [00:00<00:00, 100.71it/s]
# Processing samples: 100%|██████████| 108683/108683 [00:00<00:00, 494676.72it/s]
# Averaging log-probabilities: 100%|██████████| 1429/1429 [00:00<00:00, 232132.47it/s]
# Processing unique samples for set 0: 100%|██████████| 1429/1429 [00:00<00:00, 363715.06it/s]
# Binning samples: 100%|██████████| 4/4 [00:00<00:00, 112.62it/s]
# Processing samples: 100%|██████████| 119400/119400 [00:00<00:00, 479496.35it/s]
# Averaging log-probabilities: 100%|██████████| 1420/1420 [00:00<00:00, 176927.54it/s]
# Processing unique samples for set 1: 100%|██████████| 1420/1420 [00:00<00:00, 352087.47it/s]
# Binning samples: 100%|██████████| 4/4 [00:00<00:00, 80.26it/s]
# Processing samples: 100%|██████████| 160103/160103 [00:00<00:00, 489859.99it/s]
# Averaging log-probabilities: 100%|██████████| 1730/1730 [00:00<00:00, 149793.48it/s]
# Processing unique samples for set 2: 100%|██████████| 1730/1730 [00:00<00:00, 307229.48it/s]
# Binning samples: 100%|██████████| 4/4 [00:00<00:00, 54.61it/s]
# Processing samples: 100%|██████████| 108683/108683 [00:00<00:00, 360207.87it/s]
# Averaging log-probabilities: 100%|██████████| 1487/1487 [00:00<00:00, 168192.93it/s]
# Processing unique samples for set 0: 100%|██████████| 1487/1487 [00:00<00:00, 246762.81it/s]
# Binning samples: 100%|██████████| 4/4 [00:00<00:00, 87.24it/s]
# Processing samples: 100%|██████████| 119400/119400 [00:00<00:00, 441037.55it/s]
# Averaging log-probabilities: 100%|██████████| 1530/1530 [00:00<00:00, 229115.11it/s]
# Processing unique samples for set 1: 100%|██████████| 1530/1530 [00:00<00:00, 316231.47it/s]
# Binning samples: 100%|██████████| 4/4 [00:00<00:00, 74.04it/s]
# Processing samples: 100%|██████████| 160103/160103 [00:00<00:00, 516176.35it/s]
# Averaging log-probabilities: 100%|██████████| 1810/1810 [00:00<00:00, 263243.88it/s]
# Processing unique samples for set 2: 100%|██████████| 1810/1810 [00:00<00:00, 367671.94it/s]
# Binning samples: 100%|██████████| 4/4 [00:00<00:00, 119.44it/s]
# Processing samples: 100%|██████████| 108683/108683 [00:00<00:00, 517402.89it/s]
# Averaging log-probabilities: 100%|██████████| 1482/1482 [00:00<00:00, 250512.17it/s]
# Processing unique samples for set 0: 100%|██████████| 1482/1482 [00:00<00:00, 347473.78it/s]
# Binning samples: 100%|██████████| 4/4 [00:00<00:00, 110.63it/s]
# Processing samples: 100%|██████████| 119400/119400 [00:00<00:00, 529884.74it/s]
# Averaging log-probabilities: 100%|██████████| 1523/1523 [00:00<00:00, 261778.75it/s]
# Processing unique samples for set 1: 100%|██████████| 1523/1523 [00:00<00:00, 361922.10it/s]
# Binning samples: 100%|██████████| 4/4 [00:00<00:00, 83.32it/s]
# Processing samples: 100%|██████████| 160103/160103 [00:00<00:00, 540687.30it/s]
# Averaging log-probabilities: 100%|██████████| 1815/1815 [00:00<00:00, 262931.71it/s]
# Processing unique samples for set 2: 100%|██████████| 1815/1815 [00:00<00:00, 380271.83it/s]
# Binning samples: 100%|██████████| 4/4 [00:00<00:00, 82.68it/s]
# Processing samples: 100%|██████████| 108683/108683 [00:00<00:00, 325920.16it/s]
# Averaging log-probabilities: 100%|██████████| 1568/1568 [00:00<00:00, 175945.55it/s]
# Processing unique samples for set 0: 100%|██████████| 1568/1568 [00:00<00:00, 191801.12it/s]
# Binning samples: 100%|██████████| 4/4 [00:00<00:00, 82.55it/s]
# Processing samples: 100%|██████████| 119400/119400 [00:00<00:00, 265129.48it/s]
# Averaging log-probabilities: 100%|██████████| 1616/1616 [00:00<00:00, 191853.58it/s]
# Processing unique samples for set 1: 100%|██████████| 1616/1616 [00:00<00:00, 278322.80it/s]
# Binning samples: 100%|██████████| 4/4 [00:00<00:00, 64.04it/s]
# Processing samples: 100%|██████████| 160103/160103 [00:00<00:00, 407793.60it/s]
# Averaging log-probabilities: 100%|██████████| 1947/1947 [00:00<00:00, 202683.23it/s]
# Processing unique samples for set 2: 100%|██████████| 1947/1947 [00:00<00:00, 283080.63it/s]
# Binning samples: 100%|██████████| 4/4 [00:00<00:00, 117.56it/s]
# Processing samples: 100%|██████████| 108683/108683 [00:00<00:00, 524918.89it/s]
# Averaging log-probabilities: 100%|██████████| 1501/1501 [00:00<00:00, 285854.08it/s]
# Processing unique samples for set 0: 100%|██████████| 1501/1501 [00:00<00:00, 353509.48it/s]
# Binning samples: 100%|██████████| 4/4 [00:00<00:00, 106.58it/s]
# Processing samples: 100%|██████████| 119400/119400 [00:00<00:00, 497450.07it/s]
# Averaging log-probabilities: 100%|██████████| 1514/1514 [00:00<00:00, 240737.59it/s]
# Processing unique samples for set 1: 100%|██████████| 1514/1514 [00:00<00:00, 370899.85it/s]
# Binning samples: 100%|██████████| 4/4 [00:00<00:00, 76.53it/s]
# Processing samples: 100%|██████████| 160103/160103 [00:00<00:00, 527040.01it/s]
# Averaging log-probabilities: 100%|██████████| 1864/1864 [00:00<00:00, 257532.86it/s]
# Processing unique samples for set 2: 100%|██████████| 1864/1864 [00:00<00:00, 363416.66it/s]
# Binning samples: 100%|██████████| 4/4 [00:00<00:00, 127.24it/s]
# Processing samples: 100%|██████████| 108683/108683 [00:00<00:00, 525688.89it/s]
# Averaging log-probabilities: 100%|██████████| 1404/1404 [00:00<00:00, 271849.45it/s]
# Processing unique samples for set 0: 100%|██████████| 1404/1404 [00:00<00:00, 372921.46it/s]
# Binning samples: 100%|██████████| 4/4 [00:00<00:00, 117.23it/s]
# Processing samples: 100%|██████████| 119400/119400 [00:00<00:00, 540540.43it/s]
# Averaging log-probabilities: 100%|██████████| 1396/1396 [00:00<00:00, 261080.32it/s]
# Processing unique samples for set 1: 100%|██████████| 1396/1396 [00:00<00:00, 369299.80it/s]
# Binning samples: 100%|██████████| 4/4 [00:00<00:00, 90.42it/s]
# Processing samples: 100%|██████████| 160103/160103 [00:00<00:00, 540932.08it/s]
# Averaging log-probabilities: 100%|██████████| 1682/1682 [00:00<00:00, 233456.41it/s]
# Processing unique samples for set 2: 100%|██████████| 1682/1682 [00:00<00:00, 362250.03it/s]
# Binning samples: 100%|██████████| 4/4 [00:00<00:00, 120.46it/s]
# Processing samples: 100%|██████████| 108683/108683 [00:00<00:00, 491160.55it/s]
# Averaging log-probabilities: 100%|██████████| 1476/1476 [00:00<00:00, 243847.20it/s]
# Processing unique samples for set 0: 100%|██████████| 1476/1476 [00:00<00:00, 324601.13it/s]
# Binning samples: 100%|██████████| 4/4 [00:00<00:00, 109.35it/s]
# Processing samples: 100%|██████████| 119400/119400 [00:00<00:00, 478833.41it/s]
# Averaging log-probabilities: 100%|██████████| 1485/1485 [00:00<00:00, 253977.39it/s]
# Processing unique samples for set 1: 100%|██████████| 1485/1485 [00:00<00:00, 311069.34it/s]
# Binning samples: 100%|██████████| 4/4 [00:00<00:00, 78.98it/s]
# Processing samples: 100%|██████████| 160103/160103 [00:00<00:00, 471329.22it/s]
# Averaging log-probabilities: 100%|██████████| 1768/1768 [00:00<00:00, 216164.68it/s]
# Processing unique samples for set 2: 100%|██████████| 1768/1768 [00:00<00:00, 343550.13it/s]

# %%
#creating a new df with the results in days
if TIME_UNIT != 'days':
    df_days=post.create_posterior_df(filepath=path_days, ds = [best_sim_no_ext_hazard,best_sim,ds], ds_labels=['best fit no ext hazard','best fit','data'],rescale=scale,truth=truth_df)
else:
    df_days=df
    if path_days is not None:
        df_days.to_csv(path_days)
# Out:
# Rescaling the samples TIME by 365
# Binning samples: 100%|██████████| 4/4 [00:00<00:00, 105.09it/s]
# Processing samples: 100%|██████████| 108683/108683 [00:00<00:00, 489818.98it/s]
# Averaging log-probabilities: 100%|██████████| 1569/1569 [00:00<00:00, 258397.32it/s]
# Processing unique samples for set 0: 100%|██████████| 1569/1569 [00:00<00:00, 377602.88it/s]
# Binning samples: 100%|██████████| 4/4 [00:00<00:00, 110.79it/s]
# Processing samples: 100%|██████████| 119400/119400 [00:00<00:00, 511349.55it/s]
# Averaging log-probabilities: 100%|██████████| 1621/1621 [00:00<00:00, 243428.81it/s]
# Processing unique samples for set 1: 100%|██████████| 1621/1621 [00:00<00:00, 310171.84it/s]
# Binning samples: 100%|██████████| 4/4 [00:00<00:00, 81.19it/s]
# Processing samples: 100%|██████████| 160103/160103 [00:00<00:00, 506375.81it/s]
# Averaging log-probabilities: 100%|██████████| 1942/1942 [00:00<00:00, 252701.84it/s]
# Processing unique samples for set 2: 100%|██████████| 1942/1942 [00:00<00:00, 386419.58it/s]
# Binning samples: 100%|██████████| 4/4 [00:00<00:00, 120.94it/s]
# Processing samples: 100%|██████████| 108683/108683 [00:00<00:00, 501744.62it/s]
# Averaging log-probabilities: 100%|██████████| 1569/1569 [00:00<00:00, 222491.82it/s]
# Processing unique samples for set 0: 100%|██████████| 1569/1569 [00:00<00:00, 263561.34it/s]
# Binning samples: 100%|██████████| 4/4 [00:00<00:00, 100.07it/s]
# Processing samples: 100%|██████████| 119400/119400 [00:00<00:00, 312572.88it/s]
# Averaging log-probabilities: 100%|██████████| 1621/1621 [00:00<00:00, 185172.18it/s]
# Processing unique samples for set 1: 100%|██████████| 1621/1621 [00:00<00:00, 223871.15it/s]
# Binning samples: 100%|██████████| 4/4 [00:00<00:00, 66.93it/s]
# Processing samples: 100%|██████████| 160103/160103 [00:00<00:00, 337126.19it/s]
# Averaging log-probabilities: 100%|██████████| 1942/1942 [00:00<00:00, 80782.08it/s]
# Processing unique samples for set 2: 100%|██████████| 1942/1942 [00:00<00:00, 225395.38it/s]
# Binning samples: 100%|██████████| 4/4 [00:00<00:00, 111.37it/s]
# Processing samples: 100%|██████████| 108683/108683 [00:00<00:00, 502338.45it/s]
# Averaging log-probabilities: 100%|██████████| 1414/1414 [00:00<00:00, 253591.56it/s]
# Processing unique samples for set 0: 100%|██████████| 1414/1414 [00:00<00:00, 375744.16it/s]
# Binning samples: 100%|██████████| 4/4 [00:00<00:00, 107.74it/s]
# Processing samples: 100%|██████████| 119400/119400 [00:00<00:00, 249781.49it/s]
# Averaging log-probabilities: 100%|██████████| 1412/1412 [00:00<00:00, 129873.41it/s]
# Processing unique samples for set 1: 100%|██████████| 1412/1412 [00:00<00:00, 180515.64it/s]
# Binning samples: 100%|██████████| 4/4 [00:00<00:00, 56.84it/s]
# Processing samples: 100%|██████████| 160103/160103 [00:00<00:00, 273873.65it/s]
# Averaging log-probabilities: 100%|██████████| 1715/1715 [00:00<00:00, 65052.96it/s]
# Processing unique samples for set 2: 100%|██████████| 1715/1715 [00:00<00:00, 126352.21it/s]
# Binning samples: 100%|██████████| 4/4 [00:00<00:00, 78.22it/s]
# Processing samples: 100%|██████████| 108683/108683 [00:00<00:00, 272973.44it/s]
# Averaging log-probabilities: 100%|██████████| 1491/1491 [00:00<00:00, 114860.73it/s]
# Processing unique samples for set 0: 100%|██████████| 1491/1491 [00:00<00:00, 209708.17it/s]
# Binning samples: 100%|██████████| 4/4 [00:00<00:00, 25.31it/s]
# Processing samples: 100%|██████████| 119400/119400 [00:00<00:00, 255664.20it/s]
# Averaging log-probabilities: 100%|██████████| 1534/1534 [00:00<00:00, 166849.81it/s]
# Processing unique samples for set 1: 100%|██████████| 1534/1534 [00:00<00:00, 243272.17it/s]
# Binning samples: 100%|██████████| 4/4 [00:00<00:00, 56.33it/s]
# Processing samples: 100%|██████████| 160103/160103 [00:00<00:00, 368243.25it/s]
# Averaging log-probabilities: 100%|██████████| 1813/1813 [00:00<00:00, 194462.80it/s]
# Processing unique samples for set 2: 100%|██████████| 1813/1813 [00:00<00:00, 292280.94it/s]
# Binning samples: 100%|██████████| 4/4 [00:00<00:00, 109.05it/s]
# Processing samples: 100%|██████████| 108683/108683 [00:00<00:00, 521006.04it/s]
# Averaging log-probabilities: 100%|██████████| 1500/1500 [00:00<00:00, 257645.93it/s]
# Processing unique samples for set 0: 100%|██████████| 1500/1500 [00:00<00:00, 369368.64it/s]
# Binning samples: 100%|██████████| 4/4 [00:00<00:00, 115.13it/s]
# Processing samples: 100%|██████████| 119400/119400 [00:00<00:00, 530016.53it/s]
# Averaging log-probabilities: 100%|██████████| 1542/1542 [00:00<00:00, 264092.15it/s]
# Processing unique samples for set 1: 100%|██████████| 1542/1542 [00:00<00:00, 362493.93it/s]
# Binning samples: 100%|██████████| 4/4 [00:00<00:00, 82.29it/s]
# Processing samples: 100%|██████████| 160103/160103 [00:00<00:00, 536793.96it/s]
# Averaging log-probabilities: 100%|██████████| 1816/1816 [00:00<00:00, 263413.20it/s]
# Processing unique samples for set 2: 100%|██████████| 1816/1816 [00:00<00:00, 389091.54it/s]
# Binning samples: 100%|██████████| 4/4 [00:00<00:00, 108.90it/s]
# Processing samples: 100%|██████████| 108683/108683 [00:00<00:00, 446463.54it/s]
# Averaging log-probabilities: 100%|██████████| 1561/1561 [00:00<00:00, 254521.40it/s]
# Processing unique samples for set 0: 100%|██████████| 1561/1561 [00:00<00:00, 255444.91it/s]
# Binning samples: 100%|██████████| 4/4 [00:00<00:00, 94.76it/s]
# Processing samples: 100%|██████████| 119400/119400 [00:00<00:00, 504540.56it/s]
# Averaging log-probabilities: 100%|██████████| 1620/1620 [00:00<00:00, 239581.55it/s]
# Processing unique samples for set 1: 100%|██████████| 1620/1620 [00:00<00:00, 344387.86it/s]
# Binning samples: 100%|██████████| 4/4 [00:00<00:00, 70.59it/s]
# Processing samples: 100%|██████████| 160103/160103 [00:00<00:00, 438246.74it/s]
# Averaging log-probabilities: 100%|██████████| 1923/1923 [00:00<00:00, 169037.97it/s]
# Processing unique samples for set 2: 100%|██████████| 1923/1923 [00:00<00:00, 262853.07it/s]
# Binning samples: 100%|██████████| 4/4 [00:00<00:00, 143.46it/s]
# Processing samples: 100%|██████████| 108683/108683 [00:00<00:00, 615150.85it/s]
# Averaging log-probabilities: 100%|██████████| 1499/1499 [00:00<00:00, 307040.18it/s]
# Processing unique samples for set 0: 100%|██████████| 1499/1499 [00:00<00:00, 443639.69it/s]
# Binning samples: 100%|██████████| 4/4 [00:00<00:00, 143.84it/s]
# Processing samples: 100%|██████████| 119400/119400 [00:00<00:00, 647291.72it/s]
# Averaging log-probabilities: 100%|██████████| 1512/1512 [00:00<00:00, 325203.20it/s]
# Processing unique samples for set 1: 100%|██████████| 1512/1512 [00:00<00:00, 469692.46it/s]
# Binning samples: 100%|██████████| 4/4 [00:00<00:00, 104.06it/s]
# Processing samples: 100%|██████████| 160103/160103 [00:00<00:00, 690536.65it/s]
# Averaging log-probabilities: 100%|██████████| 1835/1835 [00:00<00:00, 347882.29it/s]
# Processing unique samples for set 2: 100%|██████████| 1835/1835 [00:00<00:00, 468587.39it/s]
# Binning samples: 100%|██████████| 4/4 [00:00<00:00, 145.43it/s]
# Processing samples: 100%|██████████| 108683/108683 [00:00<00:00, 632564.72it/s]
# Averaging log-probabilities: 100%|██████████| 1399/1399 [00:00<00:00, 319842.54it/s]
# Processing unique samples for set 0: 100%|██████████| 1399/1399 [00:00<00:00, 442721.54it/s]
# Binning samples: 100%|██████████| 4/4 [00:00<00:00, 145.87it/s]
# Processing samples: 100%|██████████| 119400/119400 [00:00<00:00, 655121.67it/s]
# Averaging log-probabilities: 100%|██████████| 1397/1397 [00:00<00:00, 322425.72it/s]
# Processing unique samples for set 1: 100%|██████████| 1397/1397 [00:00<00:00, 480400.32it/s]
# Binning samples: 100%|██████████| 4/4 [00:00<00:00, 104.58it/s]
# Processing samples: 100%|██████████| 160103/160103 [00:00<00:00, 656433.83it/s]
# Averaging log-probabilities: 100%|██████████| 1690/1690 [00:00<00:00, 317536.79it/s]
# Processing unique samples for set 2: 100%|██████████| 1690/1690 [00:00<00:00, 466463.13it/s]
# Binning samples: 100%|██████████| 4/4 [00:00<00:00, 91.29it/s]
# Processing samples: 100%|██████████| 108683/108683 [00:00<00:00, 478614.86it/s]
# Averaging log-probabilities: 100%|██████████| 1470/1470 [00:00<00:00, 249116.24it/s]
# Processing unique samples for set 0: 100%|██████████| 1470/1470 [00:00<00:00, 338306.00it/s]
# Binning samples: 100%|██████████| 4/4 [00:00<00:00, 110.09it/s]
# Processing samples: 100%|██████████| 119400/119400 [00:00<00:00, 511557.44it/s]
# Averaging log-probabilities: 100%|██████████| 1498/1498 [00:00<00:00, 244562.98it/s]
# Processing unique samples for set 1: 100%|██████████| 1498/1498 [00:00<00:00, 347169.16it/s]
# Binning samples: 100%|██████████| 4/4 [00:00<00:00, 81.42it/s]
# Processing samples: 100%|██████████| 160103/160103 [00:00<00:00, 546905.95it/s]
# Averaging log-probabilities: 100%|██████████| 1782/1782 [00:00<00:00, 287040.58it/s]
# Processing unique samples for set 2: 100%|██████████| 1782/1782 [00:00<00:00, 424697.41it/s]

# %% [markdown]
# # 4. Table of results
#
# mode is the marginalized mode,
# max_likwlihood is the sample with highest likelihood
# mode_overall is the 4D posterior mode

# %%
df
# Out:
#                                             mean                   std  \
# xc/eta                                     4.193  [2.41e-11, 2.41e-11]
# beta/eta                                 115.418  [1.36e-10, 1.36e-10]
# xc^2/epsilon                               1.117  [4.14e-12, 4.14e-12]
# xc                                         6.315  [7.62e-11, 7.62e-11]
# eta                                        1.445    [1.2e-07, 1.2e-07]
# beta                                     168.135  [1.15e-05, 1.15e-05]
# epsilon                                   35.087    [8.6e-06, 8.6e-06]
# sqrt(xc/eta)                               2.048  [1.36e-10, 1.36e-10]
# s= eta^0.5*xc^1.5/epsilon                  0.535  [9.01e-12, 9.01e-12]
# beta*xc/epsilon                           30.904        [3e-09, 3e-09]
# eta*xc/epsilon                             0.259    [4.7e-13, 4.7e-13]
# Fx=beta^2/eta*xc                        3203.982  [2.52e-08, 2.52e-08]
# Dx =beta*epsilon/eta*xc^2                104.753  [5.14e-10, 5.14e-10]
# Pk=beta*k/epsilon                           2.46  [4.62e-07, 4.62e-07]
# Fk=beta^2/eta*k                        37767.583    [0.00225, 0.00225]
# Dk =beta*epsilon/eta*k^2                16204.82  [0.000321, 0.000321]
# Fk^2/Dk=beta^3/eta*epsilon              98330.49    [0.00118, 0.00118]
# epsilon/beta^2                           0.00116  [1.26e-11, 1.26e-11]
# k/beta                                   0.00297  [1.77e-11, 1.77e-11]
# k^2/epsilon                              0.00712  [1.52e-10, 1.52e-10]
# eta/xc                                     0.238  [1.37e-12, 1.37e-12]
# beta/xc                                   27.854  [1.92e-10, 1.92e-10]
# epsilon/xc^2                               0.895  [3.32e-12, 3.32e-12]
# k/xc                                      0.0791  [9.55e-13, 9.55e-13]
# best fit no ext hazard_MedianLifetime      75.43                  0.51
# best fit no ext hazard_MaxLifetime        106.17                     0
# best fit_MedianLifetime                    73.01                  0.51
# best fit_MaxLifetime                       105.2                     0
# data_MedianLifetime                         72.5                   0.5
# data_MaxLifetime                           107.5                     0
#
#                                             mode  \
# xc/eta                                     6.502
# beta/eta                                 108.601
# xc^2/epsilon                               1.633
# xc                                        12.379
# eta                                        2.101
# beta                                     228.949
# epsilon                                  127.483
# sqrt(xc/eta)                                2.55
# s= eta^0.5*xc^1.5/epsilon                  0.535
# beta*xc/epsilon                           24.568
# eta*xc/epsilon                             0.235
# Fx=beta^2/eta*xc                        1583.517
# Dx =beta*epsilon/eta*xc^2                 67.457
# Pk=beta*k/epsilon                          0.917
# Fk=beta^2/eta*k                        46517.396
# Dk =beta*epsilon/eta*k^2               46228.601
# Fk^2/Dk=beta^3/eta*epsilon             41247.777
# epsilon/beta^2                           0.00255
# k/beta                                   0.00207
# k^2/epsilon                              0.00196
# eta/xc                                     0.154
# beta/xc                                   16.436
# epsilon/xc^2                               0.612
# k/xc                                      0.0404
# best fit no ext hazard_MedianLifetime      75.43
# best fit no ext hazard_MaxLifetime        106.17
# best fit_MedianLifetime                    73.01
# best fit_MaxLifetime                       105.2
# data_MedianLifetime                         72.5
# data_MaxLifetime                           107.5
#
#                                                                 percentile_16  \
# xc/eta                                                         [6.301, 6.708]
# beta/eta                                                   [107.778, 109.431]
# xc^2/epsilon                                                   [1.595, 1.672]
# xc                                                           [11.869, 12.911]
# eta                                                            [2.036, 2.168]
# beta                                                       [223.134, 234.916]
# epsilon                                                    [117.607, 138.189]
# sqrt(xc/eta)                                                     [2.51, 2.59]
# s= eta^0.5*xc^1.5/epsilon                                      [0.525, 0.546]
# beta*xc/epsilon                                              [23.873, 25.282]
# eta*xc/epsilon                                                  [0.23, 0.241]
# Fx=beta^2/eta*xc                                         [1515.282, 1654.825]
# Dx =beta*epsilon/eta*xc^2                                    [65.627, 69.339]
# Pk=beta*k/epsilon                                              [0.855, 0.984]
# Fk=beta^2/eta*k                                        [45321.405, 47744.947]
# Dk =beta*epsilon/eta*k^2                               [42893.523, 49822.991]
# Fk^2/Dk=beta^3/eta*epsilon                             [38367.183, 44344.646]
# epsilon/beta^2                                             [0.00239, 0.00272]
# k/beta                                                     [0.00202, 0.00213]
# k^2/epsilon                                                [0.00181, 0.00212]
# eta/xc                                                         [0.149, 0.159]
# beta/xc                                                      [15.829, 17.067]
# epsilon/xc^2                                                   [0.598, 0.627]
# k/xc                                                         [0.0387, 0.0421]
# best fit no ext hazard_MedianLifetime  [74.94000000000001, 75.94000000000001]
# best fit no ext hazard_MaxLifetime                           [106.17, 106.17]
# best fit_MedianLifetime                [72.52000000000001, 73.52000000000001]
# best fit_MaxLifetime                                           [105.2, 105.2]
# data_MedianLifetime                                             [72.01, 73.0]
# data_MaxLifetime                                               [107.5, 107.5]
#
#                                                                 percentile_50  \
# xc/eta                                                         [6.301, 6.708]
# beta/eta                                                   [107.778, 109.431]
# xc^2/epsilon                                                   [1.595, 1.672]
# xc                                                           [11.869, 12.911]
# eta                                                            [2.036, 2.168]
# beta                                                       [223.134, 234.916]
# epsilon                                                    [117.607, 138.189]
# sqrt(xc/eta)                                                     [2.51, 2.59]
# s= eta^0.5*xc^1.5/epsilon                                      [0.525, 0.546]
# beta*xc/epsilon                                              [23.873, 25.282]
# eta*xc/epsilon                                                  [0.23, 0.241]
# Fx=beta^2/eta*xc                                         [1515.282, 1654.825]
# Dx =beta*epsilon/eta*xc^2                                    [65.627, 69.339]
# Pk=beta*k/epsilon                                              [0.855, 0.984]
# Fk=beta^2/eta*k                                        [45321.405, 47744.947]
# Dk =beta*epsilon/eta*k^2                               [42893.523, 49822.991]
# Fk^2/Dk=beta^3/eta*epsilon                             [38367.183, 44344.646]
# epsilon/beta^2                                             [0.00239, 0.00272]
# k/beta                                                     [0.00202, 0.00213]
# k^2/epsilon                                                [0.00181, 0.00212]
# eta/xc                                                         [0.149, 0.159]
# beta/xc                                                      [15.829, 17.067]
# epsilon/xc^2                                                   [0.598, 0.627]
# k/xc                                                         [0.0387, 0.0421]
# best fit no ext hazard_MedianLifetime  [74.94000000000001, 75.94000000000001]
# best fit no ext hazard_MaxLifetime                           [106.17, 106.17]
# best fit_MedianLifetime                [72.52000000000001, 73.52000000000001]
# best fit_MaxLifetime                                           [105.2, 105.2]
# data_MedianLifetime                                             [72.01, 73.0]
# data_MaxLifetime                                               [107.5, 107.5]
#
#                                                                 percentile_95  \
# xc/eta                                                         [6.301, 7.142]
# beta/eta                                                   [107.778, 109.431]
# xc^2/epsilon                                                   [1.521, 1.672]
# xc                                                           [11.869, 14.044]
# eta                                                            [2.036, 2.307]
# beta                                                        [223.134, 247.32]
# epsilon                                                    [100.091, 138.189]
# sqrt(xc/eta)                                                    [2.51, 2.672]
# s= eta^0.5*xc^1.5/epsilon                                      [0.525, 0.568]
# beta*xc/epsilon                                              [23.873, 25.282]
# eta*xc/epsilon                                                  [0.23, 0.253]
# Fx=beta^2/eta*xc                                         [1515.282, 1807.217]
# Dx =beta*epsilon/eta*xc^2                                    [65.627, 69.339]
# Pk=beta*k/epsilon                                              [0.855, 0.984]
# Fk=beta^2/eta*k                                        [45321.405, 50298.087]
# Dk =beta*epsilon/eta*k^2                               [42893.523, 57871.917]
# Fk^2/Dk=beta^3/eta*epsilon                             [38367.183, 44344.646]
# epsilon/beta^2                                             [0.00239, 0.00272]
# k/beta                                                     [0.00202, 0.00224]
# k^2/epsilon                                                [0.00181, 0.00212]
# eta/xc                                                          [0.14, 0.159]
# beta/xc                                                      [15.829, 18.403]
# epsilon/xc^2                                                   [0.598, 0.657]
# k/xc                                                         [0.0387, 0.0458]
# best fit no ext hazard_MedianLifetime  [74.94000000000001, 75.94000000000001]
# best fit no ext hazard_MaxLifetime                           [106.17, 106.17]
# best fit_MedianLifetime                [72.52000000000001, 73.52000000000001]
# best fit_MaxLifetime                                           [105.2, 105.2]
# data_MedianLifetime                                             [72.01, 73.0]
# data_MaxLifetime                                               [107.5, 107.5]
#
#                                       max_likelihood mode_overall
# xc/eta                                         4.214        4.193
# beta/eta                                     114.909      115.418
# xc^2/epsilon                                   1.104        1.117
# xc                                             6.154        6.315
# eta                                             1.46        1.445
# beta                                         167.822      168.135
# epsilon                                        34.32       35.087
# sqrt(xc/eta)                                   2.053        2.048
# s= eta^0.5*xc^1.5/epsilon                      0.538        0.535
# beta*xc/epsilon                               30.093       30.904
# eta*xc/epsilon                                 0.262        0.259
# Fx=beta^2/eta*xc                            3133.569     3203.982
# Dx =beta*epsilon/eta*xc^2                    104.129      104.753
# Pk=beta*k/epsilon                              2.445         2.46
# Fk=beta^2/eta*k                            38568.658    37767.583
# Dk =beta*epsilon/eta*k^2                     15774.7     16204.82
# Fk^2/Dk=beta^3/eta*epsilon                 94299.188     98330.49
# epsilon/beta^2                               0.00122      0.00116
# k/beta                                       0.00298      0.00297
# k^2/epsilon                                  0.00728      0.00712
# eta/xc                                         0.237        0.238
# beta/xc                                        27.27       27.854
# epsilon/xc^2                                   0.906        0.895
# k/xc                                          0.0812       0.0791
# best fit no ext hazard_MedianLifetime          75.43          NaN
# best fit no ext hazard_MaxLifetime            106.17          NaN
# best fit_MedianLifetime                        73.01          NaN
# best fit_MaxLifetime                           105.2          NaN
# data_MedianLifetime                             72.5          NaN
# data_MaxLifetime                               107.5          NaN

# %%
if SAVE_PRODUCTS:
    ####GO OVER THIS BEFORE SAVING!!!!!!!!!!!!###################################################
    import pandas as pd
    import SRtools.utils as ut
    summery_csv_base_name='summery'
    # Create paths for the three summary CSV files
    mode_summary_path = os.path.join(base_products_folder, f'{summery_csv_base_name}_mode.csv')
    max_likelihood_summary_path = os.path.join(base_products_folder, f'{summery_csv_base_name}_max_likelihood.csv')
    mode_overall_summary_path = os.path.join(base_products_folder, f'{summery_csv_base_name}_mode_overall.csv')

    # Get the relevant values from df_days
    file_name = config_name+test_str
    mode_values = df_days['mode'].copy()
    max_likelihood_values = df_days['max_likelihood'].copy()
    mode_overall_values = df_days['mode_overall'].copy()
    # Get the 95% confidence intervals from df_days
    ci_values = df_days['percentile_95'].copy()
    # Convert CI values to string representation
    ci_values = ci_values.apply(lambda x: f"[{x[0]}, {x[1]}]" if isinstance(x, (list, tuple, np.ndarray)) else x)



    # Add file name as column name
    mode_values = pd.DataFrame(mode_values.values, columns=[file_name], index=mode_values.index)
    mode_values[f'{file_name} 95% CI'] = ci_values
    max_likelihood_values = pd.DataFrame(max_likelihood_values.values, columns=[file_name], index=max_likelihood_values.index)
    mode_overall_values = pd.DataFrame(mode_overall_values.values, columns=[file_name], index=mode_overall_values.index)



    # Save the data
    ut.append_or_create_csv(mode_values, mode_summary_path,override=override)
    ut.append_or_create_csv(max_likelihood_values, max_likelihood_summary_path,override=override)
    ut.append_or_create_csv(mode_overall_values, mode_overall_summary_path,override=override)

    # If in test mode, also create an error CSV with specified columns, adding file_name to column headers
    if test_mode:
        error_columns = [
            'error_mode',
            'error_max_likelihood',
            'error_mean',
            'error_mode_overall',
            'ci95_size_pct',
            'in_percentile_16_CI',
            'in_percentile_50_CI',
            'in_percentile_95_CI',
            'in_std_CI',
        ]
        # Only select error columns that exist in df_days
        columns_present = [col for col in error_columns if col in df_days.columns]
        error_df_raw = df_days[columns_present].copy()
        # Create a MultiIndex column if more than one experiment, otherwise just use file_name as suffix
        error_df = error_df_raw.rename(columns={col: f"{file_name} {col}" for col in columns_present})
        error_csv_path = os.path.join(base_products_folder, f'{summery_csv_base_name}_error.csv')
        ut.append_or_create_csv(error_df, error_csv_path, override=True)

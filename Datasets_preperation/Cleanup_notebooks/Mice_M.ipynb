# %%
# %load_ext autoreload
# %autoreload 2
import os
#change current working directory to the parent directory
import sys

# Change working directory to ../.. only if not already there
if not hasattr(sys, "_parent_dir_set"):
    parent_dir = os.path.abspath(os.path.join(os.getcwd(), ".."))
    if os.getcwd() != parent_dir:
        os.chdir(parent_dir)
    sys._parent_dir_set = parent_dir
else:
    parent_dir = sys._parent_dir_set
# Add parent_dir to sys.path only if not already present
if parent_dir not in sys.path:
    sys.path.insert(0, parent_dir)

import numpy as np
from SRtools import sr_mcmc as srmc
from SRtools import deathTimesDataSet as dtds
import matplotlib.pyplot as plt

# %% [markdown]
#  # Raw Data loading and plotting

# %%
rawDataFile = 'Rawfiles/mice_aggregated.xlsx'

# %%
properties = ['cohort','site','sex','group']
selection_criteria = {'site':['TJL','UT'],'sex':'m','group':'Control'}
cleanedDataFile = 'Cleaned_datasets/Mice_M.csv'
cohorts = dtds.dataCollectionFromExcel(rawDataFile,properties=properties)

# %%
print(cohorts.datasets.keys())
# Out:
# dict_keys(['cohort:_C2004,site:_TJL,sex:_f,group:_4-OH-PBN,sheet:_Lifespan_C2004,index:_0', 'cohort:_C2004,site:_UM,sex:_f,group:_4-OH-PBN,sheet:_Lifespan_C2004,index:_0', 'cohort:_C2004,site:_UT,sex:_f,group:_4-OH-PBN,sheet:_Lifespan_C2004,index:_0', 'cohort:_C2004,site:_TJL,sex:_m,group:_4-OH-PBN,sheet:_Lifespan_C2004,index:_0', 'cohort:_C2004,site:_UM,sex:_m,group:_4-OH-PBN,sheet:_Lifespan_C2004,index:_0', 'cohort:_C2004,site:_UT,sex:_m,group:_4-OH-PBN,sheet:_Lifespan_C2004,index:_0', 'cohort:_C2004,site:_TJL,sex:_f,group:_Asp,sheet:_Lifespan_C2004,index:_0', 'cohort:_C2004,site:_UM,sex:_f,group:_Asp,sheet:_Lifespan_C2004,index:_0', 'cohort:_C2004,site:_UT,sex:_f,group:_Asp,sheet:_Lifespan_C2004,index:_0', 'cohort:_C2004,site:_TJL,sex:_m,group:_Asp,sheet:_Lifespan_C2004,index:_0', 'cohort:_C2004,site:_UM,sex:_m,group:_Asp,sheet:_Lifespan_C2004,index:_0', 'cohort:_C2004,site:_UT,sex:_m,group:_Asp,sheet:_Lifespan_C2004,index:_0', 'cohort:_C2004,site:_TJL,sex:_f,group:_Control,sheet:_Lifespan_C2004,index:_0', 'cohort:_C2004,site:_UM,sex:_f,group:_Control,sheet:_Lifespan_C2004,index:_0', 'cohort:_C2004,site:_UT,sex:_f,group:_Control,sheet:_Lifespan_C2004,index:_0', 'cohort:_C2004,site:_TJL,sex:_m,group:_Control,sheet:_Lifespan_C2004,index:_0', 'cohort:_C2004,site:_UM,sex:_m,group:_Control,sheet:_Lifespan_C2004,index:_0', 'cohort:_C2004,site:_UT,sex:_m,group:_Control,sheet:_Lifespan_C2004,index:_0', 'cohort:_C2004,site:_TJL,sex:_f,group:_NDGA,sheet:_Lifespan_C2004,index:_0', 'cohort:_C2004,site:_UM,sex:_f,group:_NDGA,sheet:_Lifespan_C2004,index:_0', 'cohort:_C2004,site:_UT,sex:_f,group:_NDGA,sheet:_Lifespan_C2004,index:_0', 'cohort:_C2004,site:_TJL,sex:_m,group:_NDGA,sheet:_Lifespan_C2004,index:_0', 'cohort:_C2004,site:_UM,sex:_m,group:_NDGA,sheet:_Lifespan_C2004,index:_0', 'cohort:_C2004,site:_UT,sex:_m,group:_NDGA,sheet:_Lifespan_C2004,index:_0', 'cohort:_C2004,site:_TJL,sex:_f,group:_NFP,sheet:_Lifespan_C2004,index:_0', 'cohort:_C2004,site:_UM,sex:_f,group:_NFP,sheet:_Lifespan_C2004,index:_0', 'cohort:_C2004,site:_UT,sex:_f,group:_NFP,sheet:_Lifespan_C2004,index:_0', 'cohort:_C2004,site:_TJL,sex:_m,group:_NFP,sheet:_Lifespan_C2004,index:_0', 'cohort:_C2004,site:_UM,sex:_m,group:_NFP,sheet:_Lifespan_C2004,index:_0', 'cohort:_C2004,site:_UT,sex:_m,group:_NFP,sheet:_Lifespan_C2004,index:_0', 'cohort:_C2005,site:_TJL,sex:_f,group:_CAPE_hi,sheet:_Lifespan_C2005,index:_1', 'cohort:_C2005,site:_UM,sex:_f,group:_CAPE_hi,sheet:_Lifespan_C2005,index:_1', 'cohort:_C2005,site:_UT,sex:_f,group:_CAPE_hi,sheet:_Lifespan_C2005,index:_1', 'cohort:_C2005,site:_TJL,sex:_m,group:_CAPE_hi,sheet:_Lifespan_C2005,index:_1', 'cohort:_C2005,site:_UM,sex:_m,group:_CAPE_hi,sheet:_Lifespan_C2005,index:_1', 'cohort:_C2005,site:_UT,sex:_m,group:_CAPE_hi,sheet:_Lifespan_C2005,index:_1', 'cohort:_C2005,site:_TJL,sex:_f,group:_CAPE_lo,sheet:_Lifespan_C2005,index:_1', 'cohort:_C2005,site:_UM,sex:_f,group:_CAPE_lo,sheet:_Lifespan_C2005,index:_1', 'cohort:_C2005,site:_UT,sex:_f,group:_CAPE_lo,sheet:_Lifespan_C2005,index:_1', 'cohort:_C2005,site:_TJL,sex:_m,group:_CAPE_lo,sheet:_Lifespan_C2005,index:_1', 'cohort:_C2005,site:_UM,sex:_m,group:_CAPE_lo,sheet:_Lifespan_C2005,index:_1', 'cohort:_C2005,site:_UT,sex:_m,group:_CAPE_lo,sheet:_Lifespan_C2005,index:_1', 'cohort:_C2005,site:_TJL,sex:_f,group:_Control,sheet:_Lifespan_C2005,index:_1', 'cohort:_C2005,site:_UM,sex:_f,group:_Control,sheet:_Lifespan_C2005,index:_1', 'cohort:_C2005,site:_UT,sex:_f,group:_Control,sheet:_Lifespan_C2005,index:_1', 'cohort:_C2005,site:_TJL,sex:_m,group:_Control,sheet:_Lifespan_C2005,index:_1', 'cohort:_C2005,site:_UM,sex:_m,group:_Control,sheet:_Lifespan_C2005,index:_1', 'cohort:_C2005,site:_UT,sex:_m,group:_Control,sheet:_Lifespan_C2005,index:_1', 'cohort:_C2005,site:_TJL,sex:_f,group:_Enal,sheet:_Lifespan_C2005,index:_1', 'cohort:_C2005,site:_UM,sex:_f,group:_Enal,sheet:_Lifespan_C2005,index:_1', 'cohort:_C2005,site:_UT,sex:_f,group:_Enal,sheet:_Lifespan_C2005,index:_1', 'cohort:_C20 ...

# %%
print(cohorts.nDatasets())
# Out:
# 475

# %%
prop = 'cohort'
prop_values =[]
for dataset in cohorts.datasets.values():
    prop_values.append(dataset.properties[prop][0])
prop_values = list(set(prop_values))
print(prop_values)
fig, ax = plt.subplots(1,1,figsize=(10,10))
for value in prop_values:
    cohort=cohorts.get_combined_dataset(properties=[prop,'site','sex','group'],values=[value,['TJL','UT'],'m','Control'])
    cohort.plotSurvival(ax=ax,label=f"{value}, n={cohort.n}")
# Out:
# ['C2017', 'C2013', 'C2012', 'C2014', 'C2004', 'C2005', 'C2006', 'C2011', 'C2010', 'C2009', 'C2015', 'C2016', 'C2007']

# %% [markdown]
# # Choosing only relevant cohorts and sanity checking
# We aggragate all the relevant cohorts (controls) and sample with the same size distribution as the original cohorts. We look to see the spread as a sanity check.
# We then calculate the steepnes (ML/IQR) and longevity (ML) of each sampled and data cohorts.

# %%
print(list(selection_criteria.values()))
# Out:
# [['TJL', 'UT'], 'm', 'Control']

# %%
agragated_cohort = cohorts.get_combined_dataset(properties=list(selection_criteria.keys()),values=list(selection_criteria.values()))
print(agragated_cohort.n)
# Out:
# 2746

# %%
selected_cohorts = cohorts.getSubset(properties=list(selection_criteria.keys()),values=list(selection_criteria.values()))
print(selected_cohorts.nDatasets())
# Out:
# 26

# %%
selected_cohorts.plotSurvivalComparison()
# Out:
# array([<Axes: title={'center': 'Sampled datasets n datasets=100'}, xlabel='Age'>,
#        <Axes: title={'center': 'Data datasets'}, xlabel='Age'>],
#       dtype=object)

# %%
selected_cohorts.drawConfidenceEllipse(data_percentile=100,sampled_percentile=99.9)
# Out:
# <Axes: title={'center': 'Median lifetime vs Steepness Data and sampled datasets'}, xlabel='Median lifetime', ylabel='Steepness'>

# %% [markdown]
# # Cleaning outliers
# We remove outliers that are outside the sampled cohorts confidence interval  (we do each axis saparately so the elipses are a bit missleading). We the replot the spreads of the cleaned data vs sampled data (we smaple from the cleaned cohorts)

# %%
cleaned_cohorts = selected_cohorts.clean_DatasetCollection(n_samples=1000,sampled_percentile=99.9)

# %%
cleaned_cohorts.drawConfidenceEllipse(data_percentile=100,sampled_percentile=99.9)
# Out:
# <Axes: title={'center': 'Median lifetime vs Steepness Data and sampled datasets'}, xlabel='Median lifetime', ylabel='Steepness'>

# %%
cleaned_cohorts.plotSurvivalComparison()
# Out:
# array([<Axes: title={'center': 'Sampled datasets n datasets=100'}, xlabel='Age'>,
#        <Axes: title={'center': 'Data datasets'}, xlabel='Age'>],
#       dtype=object)

# %%
combined_cleaned_cohorts = cleaned_cohorts.get_combined_dataset()
print(combined_cleaned_cohorts.n)
# Out:
# 2746

# %%
combined_cleaned_cohorts.toCsv(cleanedDataFile)
